# %%
! pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66

# %%
import numpy as np
import cv2
import sys

cv2.__version__
# Out:
# '4.6.0'

# %%
# 창을 읽음
img = cv2.imread('./fig/puppy.bmp')

# 윈도우 창을 열것
cv2.namedWindow('image')
cv2.imshow('image', img)
# 어떤 버튼을 누르면
cv2.waitKey()
# 창을 닫아라
cv2.destroyAllWindows()

# %%
# 창을 읽음
img = cv2.imread('./fig/puppy__.bmp')

# 만약 파일이 없으면 에러가 발생을 하는데, 해당 문구를 넣어주면 어디서 에러 났는지를 알 수 있음
if img is None : 
    print('image read failed')
    sys.exit()

# 윈도우 창을 열것
cv2.namedWindow('image')
cv2.imshow('image', img)
# 어떤 버튼을 누르면
cv2.waitKey()
# 창을 닫아라
cv2.destroyAllWindows()
# Out:
# image read failed
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3377: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# 창을 읽음
img = cv2.imread('./fig/PD_MRI.jpeg')

# 만약 파일이 없으면 에러가 발생을 하는데, 해당 문구를 넣어주면 어디서 에러 났는지를 알 수 있음
if img is None : 
    print('image read failed')
    sys.exit()

# 윈도우 창을 열것
cv2.namedWindow('image')
cv2.imshow('image', img)
# 어떤 버튼을 누르면
cv2.waitKey()
# 창을 닫아라
cv2.destroyAllWindows()

# %%
img = cv2.imread('./fig/puppy.bmp', cv2.IMREAD_GRAYSCALE)
print(type(img))
# 세로 가로 뒤에 행렬 3개(RGB)
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (480, 640)

# %%
# gray
cv2.namedWindow('image')
cv2.imshow('image', img)

cv2.waitKey()

cv2.destroyAllWindows()

# %%
# 원래의 크기보다 줄여줌( 2 / 4 / 8)
img = cv2.imread('./fig/puppy_1280_853.jpg', cv2.IMREAD_REDUCED_COLOR_2)
print(type(img))
# 세로 가로 뒤에 행렬 3개(RGB)
print(img.shape)
cv2.namedWindow('image')
cv2.imshow('image', img)

cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>
# (427, 640, 3)

# %%
img = cv2.imread('./fig/puppy.bmp', cv2.IMREAD_COLOR)
# image resize
img_resize = cv2.resize(img, (480*2, 640*2), interpolation = cv2.INTER_AREA)

print(img_resize.shape)
cv2.namedWindow('image')
cv2.imshow('image', img)
cv2.imshow('img_resize', img_resize)

# resize한 사진 저장
cv2.imwrite('img_resize.png',img_resize)

cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# (1280, 960, 3)

# %%
img = cv2.imread('./fig/puppy.bmp', cv2.IMREAD_COLOR)
# image resize
img_resize = cv2.resize(img, (480*2, 640*2), interpolation = cv2.INTER_AREA)

# 나오는 데이터 사진 크기를 커서로 줄이거나 늘릴 수 있음
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image', img)

cv2.waitKey()

cv2.destroyAllWindows()

# %%
#
img = cv2.imread('./fig/puppy.bmp', cv2.IMREAD_GRAYSCALE)
img_re = cv2.resize(img, dsize = (400,200))

if img is None : 
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image', img)
cv2.imshow('image_re', img_re)

# sec 단위 설정 가능함
while True : 
    key = cv2.waitKey()
    if key == 27 or key == 113 :
        break

cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./fig/puppy.bmp', cv2.IMREAD_COLOR)

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

if img is None : 
    print('image read failed')
    sys.exit()
    
plt.figure(figsize = (20, 20))
plt.subplot(131), plt.imshow(img), plt.axis('off'), plt.title('img_bgr')
plt.subplot(132), plt.imshow(img_rgb), plt.axis('off'), plt.title('img_rgb')
plt.subplot(133), plt.imshow(img_gray, cmap = 'gray'), plt.axis('off'), plt.title('img_gray')
plt.show()
