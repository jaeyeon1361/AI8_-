# %%
# '시도별 전출입 인구수.xlsx' 파일 읽어 df 에 저장 후 
# nan 데이터 처리
# 서울 특별시에서 타시로 이동한 인구의 자료만 df_seoul로 추출
# 인덱으를 전입지 컬럼으로 설정
# 경기도 충청남도 강원도 전라남도의 자료 중 1997년 부터 2017년 자료만 추출해서 df_! 저장
# 년도를인덱스로 바꾸어서 df_t에 저장

# %%
import pandas as pd
import numpy as np

# %%
# '시도별 전출입 인구수.xlsx' 파일 읽어 df 에 저장 후 
df = pd.read_excel('./dataset/data/시도별 전출입 인구수.xlsx', header=0)
df
# Out:
#      전출지별     전입지별      1970      1971      1972      1973      1974  \
# 0    전출지별     전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1      전국       전국   4046536   4210164   3687938   4860418   5297969
# 2     NaN    서울특별시   1742813   1671705   1349333   1831858   2050392
# 3     NaN    부산광역시    448577    389797    362202    482061    680984
# 4     NaN    대구광역시         -         -         -         -         -
# ..    ...      ...       ...       ...       ...       ...       ...
# 320   NaN     전라북도       139       202       141       210       219
# 321   NaN     전라남도       631       965       857       952      1133
# 322   NaN     경상북도       374       619       468       576       625
# 323   NaN     경상남도       474       479       440       571      1208
# 324   NaN  제주특별자치도      9290     12427     12210     16158     19580
#
#          1975      1976      1977  ...      2008      2009      2010  \
# ...

# %%
# nan 데이터 처리
df = df.fillna(method='ffill')
df
# Out:
#         전출지별     전입지별      1970      1971      1972      1973      1974  \
# 0       전출지별     전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1         전국       전국   4046536   4210164   3687938   4860418   5297969
# 2         전국    서울특별시   1742813   1671705   1349333   1831858   2050392
# 3         전국    부산광역시    448577    389797    362202    482061    680984
# 4         전국    대구광역시         -         -         -         -         -
# ..       ...      ...       ...       ...       ...       ...       ...
# 320  제주특별자치도     전라북도       139       202       141       210       219
# 321  제주특별자치도     전라남도       631       965       857       952      1133
# 322  제주특별자치도     경상북도       374       619       468       576       625
# 323  제주특별자치도     경상남도       474       479       440       571      1208
# 324  제주특별자치도  제주특별자치도      9290     12427     12210     16158     19580
#
#          1975      1976      1977  ...      2008      2009      2010  \
# ...

# %%
# 서울 특별시에서 타시로 이동한 인구의 자료만 df_seoul로 추출
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] !='서울특별시')
mask[10:40]
# Out:
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
df_seoul = df[mask]
df_seoul
# Out:
#      전출지별     전입지별     1970     1971     1972     1973     1974     1975  \
# 19  서울특별시       전국  1448985  1419016  1210559  1647268  1819660  2937093
# 21  서울특별시    부산광역시    11568    11130    11768    16307    22220    27515
# 22  서울특별시    대구광역시        -        -        -        -        -        -
# 23  서울특별시    인천광역시        -        -        -        -        -        -
# 24  서울특별시    광주광역시        -        -        -        -        -        -
# 25  서울특별시    대전광역시        -        -        -        -        -        -
# 26  서울특별시    울산광역시        -        -        -        -        -        -
# 27  서울특별시  세종특별자치시        -        -        -        -        -        -
# 28  서울특별시      경기도   130149   150313    93333   143234   149045   253705
# 29  서울특별시      강원도     9352    12885    13561    16481    15479    27837
# 30  서울특별시     충청북도     6700     9457    10853    12617    11786    21073
# 31  서울특별시     충청남도    15954    18943    23406    27139    25509    51205
# ...

# %%
df_seoul = df_seoul.drop('전출지별', axis=1)
df_seoul
# Out:
#        전입지별     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %%
df_seoul.rename(columns={'전입지별' : '전입지'}, inplace=True)
df_seoul.set_index
# Out:
# <bound method DataFrame.set_index of         전입지     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %%
col_years = df_seoul.columns
col_years = list(map(str, range(1997, 2018)))
col_years
# Out:
# ['1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017']

# %%
col_years = df_seoul.columns
col_years = list(map(str, range(1997, 2018)))  # 1997년부터 2017년 자료만 추출

df_1 = df_seoul.loc[['경상북도', '충청남도', '강원도', '전라남도'], col_years]
df_1

df_t = df_1.T
df_t
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 4>()
#       1 col_years = df_seoul.columns
#       2 col_years = list(map(str, range(1997, 2018)))  # 1997년부터 2017년 자료만 추출
# ----> 4 df_1 = df_seoul.loc[['경상북도', '충청남도', '강원도', '전라남도'], col_years]
#       5 df_1
#       7 df_t = df_1.T
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1147, in _LocIndexer._getitem_tuple(self, tup)
#    1145 # ugly hack for GH #836
# ...

# %%
df_t.index = df_t.index.mpa(int)
df_t.index

# %%
df_t.plot(kind='area', staked=False, alpha=0.2)
pit.title('서울 -> 타시도 인구인동', sie = 12)
plt.y
